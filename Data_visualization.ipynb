# %%
import pandas as pd
from collections import Counter
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Suricata_datas.csv')
df_columns_name = df.columns.to_list()

# %%
df.rename(columns={df_columns_name[0]: 'Time', df_columns_name[1]: 'IP Source', df_columns_name[2]: 'Port Source', df_columns_name[3]: 'Sorce Port', df_columns_name[3]: 'IP Destination',
                    df_columns_name[4]: 'Destination Port', df_columns_name[5] :'Event Type', df_columns_name[6] : 'Severity', df_columns_name[7]: 'Alert Signature'}, inplace=True)

# %%
df.loc[-1] = df_columns_name
df.index = df.index + 1
df = df.sort_index()

# %%
df['Time'] = df['Time'].apply(lambda time: time.split('.')[0])

df
# Out:
#                     Time    IP Source Port Source   IP Destination  \
# 0    2023-11-20T15:28:52  10.11.7.120       54179     45.154.98.21
# 1    2023-11-20T15:29:49  10.11.7.120       54187     45.154.98.21
# 2    2023-11-20T15:29:49  10.11.7.120       54187     45.154.98.21
# 3    2023-11-20T15:29:49  10.11.7.120       54187     45.154.98.21
# 4    2023-11-20T15:29:49  10.11.7.120       54187     45.154.98.21
# ..                   ...          ...         ...              ...
# 688  2023-11-20T16:19:08  10.11.7.120       54946  188.246.224.221
# 689  2023-11-20T16:19:13  10.11.7.120       54947  188.246.224.221
# 690  2023-11-20T16:19:17  10.11.7.120       54948  188.246.224.221
# 691  2023-11-20T16:19:21  10.11.7.120       54949  188.246.224.221
# 692  2023-11-20T16:19:26  10.11.7.120       54950  188.246.224.221
#
#     Destination Port Event Type Severity  \
# 0                 80      alert        2
# 1                 80      alert        2
# 2                 80      alert        2
# 3                 80      alert        2
# 4                 80      alert        2
# ..               ...        ...      ...
# 688             2351      alert        1
# 689             2351      alert        1
# 690             2351      alert        1
# 691             2351      alert        1
# 692             2351      alert        1
#
#                                        Alert Signature
# 0                   ET POLICY curl User-Agent Outbound
# 1            ET HUNTING curl User-Agent to Dotted Quad
# 2    ET INFO Executable Download from dotted-quad Host
# 3    ET MALWARE Terse alphanumeric executable downl...
# 4                   ET POLICY curl User-Agent Outbound
# ..                                                 ...
# 688  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
# 689  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
# 690  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
# 691  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
# 692  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
#
# [693 rows x 8 columns]

# %%
df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%dT%H:%M:%S')

# %%
df
# Out:
#                    Time    IP Source Port Source   IP Destination  \
# 0   2023-11-20 15:28:52  10.11.7.120       54179     45.154.98.21
# 1   2023-11-20 15:29:49  10.11.7.120       54187     45.154.98.21
# 2   2023-11-20 15:29:49  10.11.7.120       54187     45.154.98.21
# 3   2023-11-20 15:29:49  10.11.7.120       54187     45.154.98.21
# 4   2023-11-20 15:29:49  10.11.7.120       54187     45.154.98.21
# ..                  ...          ...         ...              ...
# 688 2023-11-20 16:19:08  10.11.7.120       54946  188.246.224.221
# 689 2023-11-20 16:19:13  10.11.7.120       54947  188.246.224.221
# 690 2023-11-20 16:19:17  10.11.7.120       54948  188.246.224.221
# 691 2023-11-20 16:19:21  10.11.7.120       54949  188.246.224.221
# 692 2023-11-20 16:19:26  10.11.7.120       54950  188.246.224.221
#
#     Destination Port Event Type Severity  \
# 0                 80      alert        2
# 1                 80      alert        2
# 2                 80      alert        2
# 3                 80      alert        2
# 4                 80      alert        2
# ..               ...        ...      ...
# 688             2351      alert        1
# 689             2351      alert        1
# 690             2351      alert        1
# 691             2351      alert        1
# 692             2351      alert        1
#
#                                        Alert Signature
# 0                   ET POLICY curl User-Agent Outbound
# 1            ET HUNTING curl User-Agent to Dotted Quad
# 2    ET INFO Executable Download from dotted-quad Host
# 3    ET MALWARE Terse alphanumeric executable downl...
# 4                   ET POLICY curl User-Agent Outbound
# ..                                                 ...
# 688  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
# 689  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
# 690  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
# 691  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
# 692  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
#
# [693 rows x 8 columns]

# %%
counter_Alert_Signature = Counter()

# %%
counter_Alert_Signature.update(df['Alert Signature'])

# %%
counter_Alert_Signature = counter_Alert_Signature.most_common()

counter_Alert_Signature
# Out:
# [('ET MALWARE Darkgate Stealer CnC Checkin (POST) M2', 671),
#  ('ET MALWARE [ANY.RUN] DarkGate Check-In HTTP Header (POST)', 10),
#  ('ET POLICY curl User-Agent Outbound', 3),
#  ('SURICATA Applayer Detect protocol only one direction', 3),
#  ('ET HUNTING curl User-Agent to Dotted Quad', 2),
#  ('ET INFO Executable Download from dotted-quad Host', 1),
#  ('ET MALWARE Terse alphanumeric executable downloader high likelihood of being hostile',
#   1),
#  ('ET POLICY PE EXE or DLL Windows file download HTTP', 1),
#  ('ET HUNTING SUSPICIOUS Dotted Quad Host MZ Response', 1)]

# %%
Alert_Signature_name = []
Alert_Signature_quantity = []
for value in counter_Alert_Signature:
    Alert_Signature_name.append(value[0])
    Alert_Signature_quantity.append(value[1])
# Out:
# 671
# 10
# 3
# 3
# 2
# 1
# 1
# 1
# 1
