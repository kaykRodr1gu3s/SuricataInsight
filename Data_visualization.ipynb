# %%
import pandas as pd

# %%
df = pd.read_csv('Suricata_datas.csv')
df_columns_name = df.columns.to_list()

# %%
df.rename(columns={df_columns_name[0]: 'Time', df_columns_name[1]: 'IP Source', df_columns_name[2]: 'Port Source', df_columns_name[3]: 'Sorce Port', df_columns_name[3]: 'IP Destination',
                    df_columns_name[4]: 'Destination Port', df_columns_name[5] :'Event Type', df_columns_name[6] : 'Severity', df_columns_name[7]: 'Alert Signature'}, inplace=True)

# %%
df.loc[-1] = df_columns_name
df.index = df.index + 1
df = df.sort_index()

# %%
df
# Out:
#                                 Time    IP Source Port Source  \
# 0    2023-11-20T15:28:52.538800-0300  10.11.7.120       54179
# 1    2023-11-20T15:29:49.199095-0300  10.11.7.120       54187
# 2    2023-11-20T15:29:49.199095-0300  10.11.7.120       54187
# 3    2023-11-20T15:29:49.199095-0300  10.11.7.120       54187
# 4    2023-11-20T15:29:49.199095-0300  10.11.7.120       54187
# ..                               ...          ...         ...
# 688  2023-11-20T16:19:08.615933-0300  10.11.7.120       54946
# 689  2023-11-20T16:19:13.019895-0300  10.11.7.120       54947
# 690  2023-11-20T16:19:17.419765-0300  10.11.7.120       54948
# 691  2023-11-20T16:19:21.834357-0300  10.11.7.120       54949
# 692  2023-11-20T16:19:26.230989-0300  10.11.7.120       54950
#
#       IP Destination Destination Port Event Type Severity  \
# 0       45.154.98.21               80      alert        2
# 1       45.154.98.21               80      alert        2
# 2       45.154.98.21               80      alert        2
# 3       45.154.98.21               80      alert        2
# 4       45.154.98.21               80      alert        2
# ..               ...              ...        ...      ...
# 688  188.246.224.221             2351      alert        1
# 689  188.246.224.221             2351      alert        1
# 690  188.246.224.221             2351      alert        1
# 691  188.246.224.221             2351      alert        1
# 692  188.246.224.221             2351      alert        1
#
#                                        Alert Signature
# 0                   ET POLICY curl User-Agent Outbound
# 1            ET HUNTING curl User-Agent to Dotted Quad
# 2    ET INFO Executable Download from dotted-quad Host
# 3    ET MALWARE Terse alphanumeric executable downl...
# 4                   ET POLICY curl User-Agent Outbound
# ..                                                 ...
# 688  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
# 689  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
# 690  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
# 691  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
# 692  ET MALWARE Darkgate Stealer CnC Checkin (POST) M2
#
# [693 rows x 8 columns]
